# %% [markdown]
# ## Red and White Wine Quality Analysis
#
# **Data Bootcamp - Fall 2018 MBA**
#
# **Caroline Packowski, Gabrielle Sart and Kaitlin Slattery**

# %% [markdown]
# ### Introduction
#
# For our course project, we set out to study how a wine's chemical composition (pH, alcohol, residual sugar, etc.) affects quality.
#
# By examining each of these chemical attributes, and running a regression with wine quality, our goal is to determine which attribute has the greatest impact on quality. This exercise has real-world impact, in that it can be used as a guide for recommending and purchasing wine.
#
# First, we will study TBC
#
# Next, we will TBC
#
# Finally, we will TBC

# %% [markdown]
# ### Packages
#
# - We will use pandas to import, manage and analyze our data
# - We will use matplotlib to plot and visualize results
# - We will use datetime to check today's date
# - We will use sys to convert to Python
# - We will use numpy for specific functionality and computing
# - We will use seaborn for more advanced visualization
# - We will use statsmodels.api for statistical modeling and regressions
# - We will use statsmodels.formula.api for statistical modeling and regressions

# %%
# import packages 
import pandas as pd                   # data management
import matplotlib.pyplot as plt       # graphics 
import datetime as dt                 # check today's date 
import sys                            # check Python version 
import numpy as np                    # scientific computing   
import seaborn as sns                 # data visualization 
import statsmodels.api as sm          # statistical modeling
import statsmodels.formula.api as smf 


from sklearn.preprocessing import StandardScaler  # For scaling dataset
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation #For clustering
from sklearn.mixture import GaussianMixture #For GMM clustering
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Data Set Information
#
# The data sets we have pulled come essentially from Kaggle. We pulled one data set for white wine and another for red wine.
#
# Our dependent variable is Quality.
#
# Our independent variables are as follows:
# - Fixed acidity: acidity produced in the body from sources other than carbon dioxide
# - Volatile acidity: acidity that is typically a by-product of fermentation, but can also indicate spoilage
# - Citric acid: a weak organic acid often used as a natural preservative or additive to add a sour taste
# - Residual sugar: refers to any natural grape sugars that are leftover after fermentation ceases; fermentation uses up sugars as the yeasts consume it
# - Chlorides: compounds responsible for salty taste
# - Free sulfur dioxide: sulphur dioxide not associated with wine molecules
# - Total sulfur dioxide: composed of free and bound sulphur dioxide, use as a preservative because of its anti-oxidative and anti-microbial properties
# - Density: in the case of wine, it is primarily determined by the concentration of alcohol, sugar, glycerol, and other dissolved solids
# - pH: used as a measure of ripeness in relation to acidity
# - Sulphates: a salt or ester of sulfuric acid, often used for industrial cleansing purposes
# - Alcohol: also known by its chemical name ethanol, is a psychoactive substance that is the active ingredient in drinks such as beer, wine, and distilled spirits
#
# While we will study each independent variable's particular effect on the depend variable, we understand that some effects may be interrelated by chemical processes.

# %%
url_white = "https://raw.githubusercontent.com/krs520/Data-Bootcamp-Project/master/wineQualityWhites.csv" 
url_red = "https://raw.githubusercontent.com/krs520/Data-Bootcamp-Project/master/wineQualityReds.csv"

dfwhite = pd.read_csv(url_white) # Read in dataset on white wine quality 
dfred = pd.read_csv(url_red) # Read in dataset on red wine quality 

dfwhite = dfwhite.rename(columns={'Unnamed: 0':'wine number', 'fixed.acidity':'fixed_acidity', 'volatile.acidity':'volatile_acidity',
                                 'citric.acid':'citric_acid','residual.sugar':'residual_sugar','total.sulfur.dioxide':'total_sulfur_dioxide',
                                 'free.sulfur.dioxide':'free_sulfur_dioxide'}) # Rename the columns 
dfred = dfred.rename(columns={'Unnamed: 0':'wine number','fixed.acidity':'fixed_acidity', 'volatile.acidity':'volatile_acidity',
                                 'citric.acid':'citric_acid', 'residual.sugar':'residual_sugar', 'total.sulfur.dioxide':'total_sulfur_dioxide',
                                 'free.sulfur.dioxide':'free_sulfur_dioxide'}) # Rename the columns 

dfwhite['type']='White' # Added a column to dfwhite for 'type' = 'White'
dfred['type']='Red' # Added a column to dfred for 'type' = 'Red'

dfwhite = dfwhite.set_index(['wine number', 'type']) # Set two indexes 
dfred = dfred.set_index(['wine number', 'type']) # Set two indexes

# %%
# What do we have? 

for df in [dfwhite, dfred]:
    print('Type:', type(df), '\n')
    print('Dimensions:', df.shape, '\n')
    print('Variables:', df.columns.tolist(), '\n \n')
# Out:
# Type: <class 'pandas.core.frame.DataFrame'>
#
# Dimensions: (4898, 12)
#
# Variables: ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
#
#
# Type: <class 'pandas.core.frame.DataFrame'>
#
# Dimensions: (1599, 12)
#
# Variables: ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %% [markdown]
# **White Wine Data Set Information**

# %%
# Lets take a look at the white wine data 

dfwhite
# Out:
#                    fixed_acidity  volatile_acidity  citric_acid  \
# wine number type
# 1           White            7.0             0.270         0.36
# 2           White            6.3             0.300         0.34
# 3           White            8.1             0.280         0.40
# 4           White            7.2             0.230         0.32
# 5           White            7.2             0.230         0.32
# 6           White            8.1             0.280         0.40
# 7           White            6.2             0.320         0.16
# 8           White            7.0             0.270         0.36
# 9           White            6.3             0.300         0.34
# 10          White            8.1             0.220         0.43
# 11          White            8.1             0.270         0.41
# 12          White            8.6             0.230         0.40
# 13          White            7.9             0.180         0.37
# 14          White            6.6             0.160         0.40
# 15          White            8.3             0.420         0.62
# 16          White            6.6             0.170         0.38
# 17          White            6.3             0.480         0.04
# 18          White            6.2             0.660         0.48
# 19          White            7.4             0.340         0.42
# 20          White            6.5             0.310         0.14
# 21          White            6.2             0.660         0.48
# 22          White            6.4             0.310         0.38
# 23          White            6.8             0.260         0.42
# 24          White            7.6             0.670         0.14
# 25          White            6.6             0.270         0.41
# 26          White            7.0             0.250         0.32
# 27          White            6.9             0.240         0.35
# 28          White            7.0             0.280         0.39
# 29          White            7.4             0.270         0.48
# 30          White            7.2             0.320         0.36
# ...                          ...               ...          ...
# 4869        White            5.8             0.230         0.31
# 4870        White            6.6             0.240         0.33
# 4871        White            6.1             0.320         0.28
# 4872        White            5.0             0.200         0.40
# 4873        White            6.0             0.420         0.41
# 4874        White            5.7             0.210         0.32
# 4875        White            5.6             0.200         0.36
# 4876        White            7.4             0.220         0.26
# 4877        White            6.2             0.380         0.42
# 4878        White            5.9             0.540         0.00
# 4879        White            6.2             0.530         0.02
# 4880        White            6.6             0.340         0.40
# 4881        White            6.6             0.340         0.40
# 4882        White            5.0             0.235         0.27
# 4883        White            5.5             0.320         0.13
# 4884        White            4.9             0.470         0.17
# 4885        White            6.5             0.330         0.38
# 4886        White            6.6             0.340         0.40
# 4887        White            6.2             0.210         0.28
# 4888        White            6.2             0.410         0.22
# 4889        White            6.8             0.220         0.36
# 4890        White            4.9             0.235         0.27
# 4891        White            6.1             0.340         0.29
# 4892        White            5.7             0.210         0.32
# 4893        White            6.5             0.230         0.38
# 4894        White            6.2             0.210         0.29
# 4895        White            6.6             0.320         0.36
# 4896        White            6.5             0.240         0.19
# 4897        White            5.5             0.290         0.30
# 4898        White            6.0             0.210         0.38
#
#                    residual_sugar  chlorides  free_sulfur_dioxide  \
# wine number type
# 1           White           20.70      0.045                 45.0
# 2           White            1.60      0.049                 14.0
# 3           White            6.90      0.050                 30.0
# 4           White            8.50      0.058                 47.0
# 5           White            8.50      0.058                 47.0
# 6           White            6.90      0.050                 30.0
# 7           White            7.00      0.045                 30.0
# 8           White           20.70      0.045                 45.0
# 9           White            1.60      0.049                 14.0
# 10          White            1.50      0.044                 28.0
# 11          White            1.45      0.033                 11.0
# 12          White            4.20      0.035                 17.0
# 13          White            1.20      0.040                 16.0
# 14          White            1.50      0.044                 48.0
# 15          White           19.25      0.040                 41.0
# 16          White            1.50      0.032                 28.0
# 17          White            1.10      0.046                 30.0
# 18          White            1.20      0.029                 29.0
# 19          White            1.10      0.033                 17.0
# 20          White            7.50      0.044                 34.0
# 21          White            1.20      0.029                 29.0
# 22          White            2.90      0.038                 19.0
# 23          White            1.70      0.049                 41.0
# 24          White            1.50      0.074                 25.0
# 25          White            1.30      0.052                 16.0
# 26          White            9.00      0.046                 56.0
# 27          White            1.00      0.052                 35.0
# 28          White            8.70      0.051                 32.0
# 29          White            1.10      0.047                 17.0
# 30          White            2.00      0.033                 37.0
# ...                           ...        ...                  ...
# 4869        White            4.50      0.046                 42.0
# 4870        White           10.10      0.032                  8.0
# 4871        White            6.60      0.021                 29.0
# 4872        White            1.90      0.015                 20.0
# 4873        White           12.40      0.032                 50.0
# 4874        White            1.60      0.030                 33.0
# 4875        White            2.50      0.048                 16.0
# 4876        White            1.20      0.035                 18.0
# 4877        White            2.50      0.038                 34.0
# 4878        White            0.80      0.032                 12.0
# 4879        White            0.90      0.035                  6.0
# 4880        White            8.10      0.046                 68.0
# 4881        White            8.10      0.046                 68.0
# 4882        White           11.75      0.030                 34.0
# 4883        White            1.30      0.037                 45.0
# 4884        White            1.90      0.035                 60.0
# 4885        White            8.30      0.048                 68.0
# 4886        White            8.10      0.046                 68.0
# 4887        White            5.70      0.028                 45.0
# 4888        White            1.90      0.023                  5.0
# 4889        White            1.20      0.052                 38.0
# 4890        White           11.75      0.030                 34.0
# 4891        White            2.20      0.036                 25.0
# 4892        White            0.90      0.038                 38.0
# 4893        White            1.30      0.032                 29.0
# 4894        White            1.60      0.039                 24.0
# 4895        White            8.00      0.047                 57.0
# 4896        White            1.20      0.041                 30.0
# 4897        White            1.10      0.022                 20.0
# 4898        White            0.80      0.020                 22.0
#
#                    total_sulfur_dioxide  density    pH  sulphates    alcohol  \
# wine number type
# 1           White                 170.0  1.00100  3.00       0.45   8.800000
# 2           White                 132.0  0.99400  3.30       0.49   9.500000
# 3           White                  97.0  0.99510  3.26       0.44  10.100000
# 4           White                 186.0  0.99560  3.19       0.40   9.900000
# 5           White                 186.0  0.99560  3.19       0.40   9.900000
# 6           White                  97.0  0.99510  3.26       0.44  10.100000
# 7           White                 136.0  0.99490  3.18       0.47   9.600000
# 8           White                 170.0  1.00100  3.00       0.45   8.800000
# 9           White                 132.0  0.99400  3.30       0.49   9.500000
# 10          White                 129.0  0.99380  3.22       0.45  11.000000
# 11          White                  63.0  0.99080  2.99       0.56  12.000000
# 12          White                 109.0  0.99470  3.14       0.53   9.700000
# 13          White                  75.0  0.99200  3.18       0.63  10.800000
# 14          White                 143.0  0.99120  3.54       0.52  12.400000
# 15          White                 172.0  1.00020  2.98       0.67   9.700000
# 16          White                 112.0  0.99140  3.25       0.55  11.400000
# 17          White                  99.0  0.99280  3.24       0.36   9.600000
# 18          White                  75.0  0.98920  3.33       0.39  12.800000
# 19          White                 171.0  0.99170  3.12       0.53  11.300000
# 20          White                 133.0  0.99550  3.22       0.50   9.500000
# 21          White                  75.0  0.98920  3.33       0.39  12.800000
# 22          White                 102.0  0.99120  3.17       0.35  11.000000
# 23          White                 122.0  0.99300  3.47       0.48  10.500000
# 24          White                 168.0  0.99370  3.05       0.51   9.300000
# 25          White                 142.0  0.99510  3.42       0.47  10.000000
# 26          White                 245.0  0.99550  3.25       0.50  10.400000
# 27          White                 146.0  0.99300  3.45       0.44  10.000000
# 28          White                 141.0  0.99610  3.38       0.53  10.500000
# 29          White                 132.0  0.99140  3.19       0.49  11.600000
# 30          White                 114.0  0.99060  3.10       0.71  12.300000
# ...                                 ...      ...   ...        ...        ...
# 4869        White                 124.0  0.99324  3.31       0.64  10.800000
# 4870        White                  81.0  0.99626  3.19       0.51   9.800000
# 4871        White                 132.0  0.99188  3.15       0.36  11.450000
# 4872        White                  98.0  0.98970  3.37       0.55  12.050000
# 4873        White                 179.0  0.99622  3.14       0.60   9.700000
# 4874        White                 122.0  0.99044  3.33       0.52  11.900000
# 4875        White                 125.0  0.99282  3.49       0.49  10.000000
# 4876        White                  97.0  0.99245  3.12       0.41   9.700000
# 4877        White                 117.0  0.99132  3.36       0.59  11.600000
# 4878        White                  82.0  0.99286  3.25       0.36   8.800000
# 4879        White                  81.0  0.99234  3.24       0.35   9.500000
# 4880        White                 170.0  0.99494  3.15       0.50   9.533333
# 4881        White                 170.0  0.99494  3.15       0.50   9.533333
# 4882        White                 118.0  0.99540  3.07       0.50   9.400000
# 4883        White                 156.0  0.99184  3.26       0.38  10.700000
# 4884        White                 148.0  0.98964  3.27       0.35  11.500000
# 4885        White                 174.0  0.99492  3.14       0.50   9.600000
# 4886        White                 170.0  0.99494  3.15       0.50   9.550000
# 4887        White                 121.0  0.99168  3.21       1.08  12.150000
# 4888        White                  56.0  0.98928  3.04       0.79  13.000000
# 4889        White                 127.0  0.99330  3.04       0.54   9.200000
# 4890        White                 118.0  0.99540  3.07       0.50   9.400000
# 4891        White                 100.0  0.98938  3.06       0.44  11.800000
# 4892        White                 121.0  0.99074  3.24       0.46  10.600000
# 4893        White                 112.0  0.99298  3.29       0.54   9.700000
# 4894        White                  92.0  0.99114  3.27       0.50  11.200000
# 4895        White                 168.0  0.99490  3.15       0.46   9.600000
# 4896        White                 111.0  0.99254  2.99       0.46   9.400000
# 4897        White                 110.0  0.98869  3.34       0.38  12.800000
# 4898        White                  98.0  0.98941  3.26       0.32  11.800000
#
#                    quality
# wine number type
# 1           White        6
# 2           White        6
# 3           White        6
# 4           White        6
# 5           White        6
# 6           White        6
# 7           White        6
# 8           White        6
# 9           White        6
# 10          White        6
# 11          White        5
# 12          White        5
# 13          White        5
# 14          White        7
# 15          White        5
# 16          White        7
# 17          White        6
# 18          White        8
# 19          White        6
# 20          White        5
# 21          White        8
# 22          White        7
# 23          White        8
# 24          White        5
# 25          White        6
# 26          White        6
# 27          White        6
# 28          White        6
# 29          White        6
# 30          White        7
# ...                    ...
# 4869        White        6
# 4870        White        6
# 4871        White        7
# 4872        White        6
# 4873        White        5
# 4874        White        6
# 4875        White        6
# 4876        White        6
# 4877        White        7
# 4878        White        5
# 4879        White        4
# 4880        White        6
# 4881        White        6
# 4882        White        6
# 4883        White        5
# 4884        White        6
# 4885        White        5
# 4886        White        6
# 4887        White        7
# 4888        White        7
# 4889        White        5
# 4890        White        6
# 4891        White        6
# 4892        White        6
# 4893        White        5
# 4894        White        6
# 4895        White        5
# 4896        White        6
# 4897        White        7
# 4898        White        6
#
# [4898 rows x 12 columns]

# %%
# Looking at the white wine data set we can group by quality score and find average of each variable

dfwhite.groupby('quality')['fixed_acidity','volatile_acidity', 'citric_acid', 
            'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 
            'density', 'pH', 'sulphates', 'alcohol'].mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3             7.600000          0.333250     0.336000        6.392500
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality
# 3         0.054300            53.325000            170.600000  0.994884
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# 7         0.038191            34.125568            125.114773  0.992452
# 8         0.038314            36.720000            126.165714  0.992236
# 9         0.027400            33.400000            116.000000  0.991460
#
#                pH  sulphates    alcohol
# quality
# 3        3.187500   0.474500  10.345000
# 4        3.182883   0.476135  10.152454
# 5        3.168833   0.482203   9.808840
# 6        3.188599   0.491106  10.575372
# 7        3.213898   0.503102  11.367936
# 8        3.218686   0.486229  11.636000
# 9        3.308000   0.466000  12.180000

# %% [markdown]
# **Red Wine Data Set Information**

# %%
# Lets take a look at the red wine data 

dfred
# Out:
#                   fixed_acidity  volatile_acidity  citric_acid  \
# wine number type
# 1           Red             7.4             0.700         0.00
# 2           Red             7.8             0.880         0.00
# 3           Red             7.8             0.760         0.04
# 4           Red            11.2             0.280         0.56
# 5           Red             7.4             0.700         0.00
# 6           Red             7.4             0.660         0.00
# 7           Red             7.9             0.600         0.06
# 8           Red             7.3             0.650         0.00
# 9           Red             7.8             0.580         0.02
# 10          Red             7.5             0.500         0.36
# 11          Red             6.7             0.580         0.08
# 12          Red             7.5             0.500         0.36
# 13          Red             5.6             0.615         0.00
# 14          Red             7.8             0.610         0.29
# 15          Red             8.9             0.620         0.18
# 16          Red             8.9             0.620         0.19
# 17          Red             8.5             0.280         0.56
# 18          Red             8.1             0.560         0.28
# 19          Red             7.4             0.590         0.08
# 20          Red             7.9             0.320         0.51
# 21          Red             8.9             0.220         0.48
# 22          Red             7.6             0.390         0.31
# 23          Red             7.9             0.430         0.21
# 24          Red             8.5             0.490         0.11
# 25          Red             6.9             0.400         0.14
# 26          Red             6.3             0.390         0.16
# 27          Red             7.6             0.410         0.24
# 28          Red             7.9             0.430         0.21
# 29          Red             7.1             0.710         0.00
# 30          Red             7.8             0.645         0.00
# ...                         ...               ...          ...
# 1570        Red             6.2             0.510         0.14
# 1571        Red             6.4             0.360         0.53
# 1572        Red             6.4             0.380         0.14
# 1573        Red             7.3             0.690         0.32
# 1574        Red             6.0             0.580         0.20
# 1575        Red             5.6             0.310         0.78
# 1576        Red             7.5             0.520         0.40
# 1577        Red             8.0             0.300         0.63
# 1578        Red             6.2             0.700         0.15
# 1579        Red             6.8             0.670         0.15
# 1580        Red             6.2             0.560         0.09
# 1581        Red             7.4             0.350         0.33
# 1582        Red             6.2             0.560         0.09
# 1583        Red             6.1             0.715         0.10
# 1584        Red             6.2             0.460         0.29
# 1585        Red             6.7             0.320         0.44
# 1586        Red             7.2             0.390         0.44
# 1587        Red             7.5             0.310         0.41
# 1588        Red             5.8             0.610         0.11
# 1589        Red             7.2             0.660         0.33
# 1590        Red             6.6             0.725         0.20
# 1591        Red             6.3             0.550         0.15
# 1592        Red             5.4             0.740         0.09
# 1593        Red             6.3             0.510         0.13
# 1594        Red             6.8             0.620         0.08
# 1595        Red             6.2             0.600         0.08
# 1596        Red             5.9             0.550         0.10
# 1597        Red             6.3             0.510         0.13
# 1598        Red             5.9             0.645         0.12
# 1599        Red             6.0             0.310         0.47
#
#                   residual_sugar  chlorides  free_sulfur_dioxide  \
# wine number type
# 1           Red              1.9      0.076                 11.0
# 2           Red              2.6      0.098                 25.0
# 3           Red              2.3      0.092                 15.0
# 4           Red              1.9      0.075                 17.0
# 5           Red              1.9      0.076                 11.0
# 6           Red              1.8      0.075                 13.0
# 7           Red              1.6      0.069                 15.0
# 8           Red              1.2      0.065                 15.0
# 9           Red              2.0      0.073                  9.0
# 10          Red              6.1      0.071                 17.0
# 11          Red              1.8      0.097                 15.0
# 12          Red              6.1      0.071                 17.0
# 13          Red              1.6      0.089                 16.0
# 14          Red              1.6      0.114                  9.0
# 15          Red              3.8      0.176                 52.0
# 16          Red              3.9      0.170                 51.0
# 17          Red              1.8      0.092                 35.0
# 18          Red              1.7      0.368                 16.0
# 19          Red              4.4      0.086                  6.0
# 20          Red              1.8      0.341                 17.0
# 21          Red              1.8      0.077                 29.0
# 22          Red              2.3      0.082                 23.0
# 23          Red              1.6      0.106                 10.0
# 24          Red              2.3      0.084                  9.0
# 25          Red              2.4      0.085                 21.0
# 26          Red              1.4      0.080                 11.0
# 27          Red              1.8      0.080                  4.0
# 28          Red              1.6      0.106                 10.0
# 29          Red              1.9      0.080                 14.0
# 30          Red              2.0      0.082                  8.0
# ...                          ...        ...                  ...
# 1570        Red              1.9      0.056                 15.0
# 1571        Red              2.2      0.230                 19.0
# 1572        Red              2.2      0.038                 15.0
# 1573        Red              2.2      0.069                 35.0
# 1574        Red              2.4      0.075                 15.0
# 1575        Red             13.9      0.074                 23.0
# 1576        Red              2.2      0.060                 12.0
# 1577        Red              1.6      0.081                 16.0
# 1578        Red              5.1      0.076                 13.0
# 1579        Red              1.8      0.118                 13.0
# 1580        Red              1.7      0.053                 24.0
# 1581        Red              2.4      0.068                  9.0
# 1582        Red              1.7      0.053                 24.0
# 1583        Red              2.6      0.053                 13.0
# 1584        Red              2.1      0.074                 32.0
# 1585        Red              2.4      0.061                 24.0
# 1586        Red              2.6      0.066                 22.0
# 1587        Red              2.4      0.065                 34.0
# 1588        Red              1.8      0.066                 18.0
# 1589        Red              2.5      0.068                 34.0
# 1590        Red              7.8      0.073                 29.0
# 1591        Red              1.8      0.077                 26.0
# 1592        Red              1.7      0.089                 16.0
# 1593        Red              2.3      0.076                 29.0
# 1594        Red              1.9      0.068                 28.0
# 1595        Red              2.0      0.090                 32.0
# 1596        Red              2.2      0.062                 39.0
# 1597        Red              2.3      0.076                 29.0
# 1598        Red              2.0      0.075                 32.0
# 1599        Red              3.6      0.067                 18.0
#
#                   total_sulfur_dioxide  density    pH  sulphates  alcohol  \
# wine number type
# 1           Red                   34.0  0.99780  3.51       0.56      9.4
# 2           Red                   67.0  0.99680  3.20       0.68      9.8
# 3           Red                   54.0  0.99700  3.26       0.65      9.8
# 4           Red                   60.0  0.99800  3.16       0.58      9.8
# 5           Red                   34.0  0.99780  3.51       0.56      9.4
# 6           Red                   40.0  0.99780  3.51       0.56      9.4
# 7           Red                   59.0  0.99640  3.30       0.46      9.4
# 8           Red                   21.0  0.99460  3.39       0.47     10.0
# 9           Red                   18.0  0.99680  3.36       0.57      9.5
# 10          Red                  102.0  0.99780  3.35       0.80     10.5
# 11          Red                   65.0  0.99590  3.28       0.54      9.2
# 12          Red                  102.0  0.99780  3.35       0.80     10.5
# 13          Red                   59.0  0.99430  3.58       0.52      9.9
# 14          Red                   29.0  0.99740  3.26       1.56      9.1
# 15          Red                  145.0  0.99860  3.16       0.88      9.2
# 16          Red                  148.0  0.99860  3.17       0.93      9.2
# 17          Red                  103.0  0.99690  3.30       0.75     10.5
# 18          Red                   56.0  0.99680  3.11       1.28      9.3
# 19          Red                   29.0  0.99740  3.38       0.50      9.0
# 20          Red                   56.0  0.99690  3.04       1.08      9.2
# 21          Red                   60.0  0.99680  3.39       0.53      9.4
# 22          Red                   71.0  0.99820  3.52       0.65      9.7
# 23          Red                   37.0  0.99660  3.17       0.91      9.5
# 24          Red                   67.0  0.99680  3.17       0.53      9.4
# 25          Red                   40.0  0.99680  3.43       0.63      9.7
# 26          Red                   23.0  0.99550  3.34       0.56      9.3
# 27          Red                   11.0  0.99620  3.28       0.59      9.5
# 28          Red                   37.0  0.99660  3.17       0.91      9.5
# 29          Red                   35.0  0.99720  3.47       0.55      9.4
# 30          Red                   16.0  0.99640  3.38       0.59      9.8
# ...                                ...      ...   ...        ...      ...
# 1570        Red                   34.0  0.99396  3.48       0.57     11.5
# 1571        Red                   35.0  0.99340  3.37       0.93     12.4
# 1572        Red                   25.0  0.99514  3.44       0.65     11.1
# 1573        Red                  104.0  0.99632  3.33       0.51      9.5
# 1574        Red                   50.0  0.99467  3.58       0.67     12.5
# 1575        Red                   92.0  0.99677  3.39       0.48     10.5
# 1576        Red                   20.0  0.99474  3.26       0.64     11.8
# 1577        Red                   29.0  0.99588  3.30       0.78     10.8
# 1578        Red                   27.0  0.99622  3.54       0.60     11.9
# 1579        Red                   20.0  0.99540  3.42       0.67     11.3
# 1580        Red                   32.0  0.99402  3.54       0.60     11.3
# 1581        Red                   26.0  0.99470  3.36       0.60     11.9
# 1582        Red                   32.0  0.99402  3.54       0.60     11.3
# 1583        Red                   27.0  0.99362  3.57       0.50     11.9
# 1584        Red                   98.0  0.99578  3.33       0.62      9.8
# 1585        Red                   34.0  0.99484  3.29       0.80     11.6
# 1586        Red                   48.0  0.99494  3.30       0.84     11.5
# 1587        Red                   60.0  0.99492  3.34       0.85     11.4
# 1588        Red                   28.0  0.99483  3.55       0.66     10.9
# 1589        Red                  102.0  0.99414  3.27       0.78     12.8
# 1590        Red                   79.0  0.99770  3.29       0.54      9.2
# 1591        Red                   35.0  0.99314  3.32       0.82     11.6
# 1592        Red                   26.0  0.99402  3.67       0.56     11.6
# 1593        Red                   40.0  0.99574  3.42       0.75     11.0
# 1594        Red                   38.0  0.99651  3.42       0.82      9.5
# 1595        Red                   44.0  0.99490  3.45       0.58     10.5
# 1596        Red                   51.0  0.99512  3.52       0.76     11.2
# 1597        Red                   40.0  0.99574  3.42       0.75     11.0
# 1598        Red                   44.0  0.99547  3.57       0.71     10.2
# 1599        Red                   42.0  0.99549  3.39       0.66     11.0
#
#                   quality
# wine number type
# 1           Red         5
# 2           Red         5
# 3           Red         5
# 4           Red         6
# 5           Red         5
# 6           Red         5
# 7           Red         5
# 8           Red         7
# 9           Red         7
# 10          Red         5
# 11          Red         5
# 12          Red         5
# 13          Red         5
# 14          Red         5
# 15          Red         5
# 16          Red         5
# 17          Red         7
# 18          Red         5
# 19          Red         4
# 20          Red         6
# 21          Red         6
# 22          Red         5
# 23          Red         5
# 24          Red         5
# 25          Red         6
# 26          Red         5
# 27          Red         5
# 28          Red         5
# 29          Red         5
# 30          Red         6
# ...                   ...
# 1570        Red         6
# 1571        Red         6
# 1572        Red         6
# 1573        Red         5
# 1574        Red         6
# 1575        Red         6
# 1576        Red         6
# 1577        Red         6
# 1578        Red         6
# 1579        Red         6
# 1580        Red         5
# 1581        Red         6
# 1582        Red         5
# 1583        Red         5
# 1584        Red         5
# 1585        Red         7
# 1586        Red         6
# 1587        Red         6
# 1588        Red         6
# 1589        Red         6
# 1590        Red         5
# 1591        Red         6
# 1592        Red         6
# 1593        Red         6
# 1594        Red         6
# 1595        Red         5
# 1596        Red         6
# 1597        Red         6
# 1598        Red         5
# 1599        Red         6
#
# [1599 rows x 12 columns]

# %%
# Looking at the red data frame, grouping by quality score and finding average of each variable

dfred.groupby('quality')['fixed_acidity','volatile_acidity', 'citric_acid', 
            'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 
            'density', 'pH', 'sulphates', 'alcohol'].mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# 8         0.068444            13.277778             33.444444  0.995212
#
#                pH  sulphates    alcohol
# quality
# 3        3.398000   0.570000   9.955000
# 4        3.381509   0.596415  10.265094
# 5        3.304949   0.620969   9.899706
# 6        3.318072   0.675329  10.629519
# 7        3.290754   0.741256  11.465913
# 8        3.267222   0.767778  12.094444

# %% [markdown]
# **Merge the Two DataFrames**

# %%
# Want to merge it into one dataset, each with another column for Type - Red or White

frames = [dfwhite, dfred]
df = pd.concat(frames) # Create a new dataframe merging dfwhite and dfred 

df
# Out:
#                    fixed_acidity  volatile_acidity  citric_acid  \
# wine number type
# 1           White            7.0             0.270         0.36
# 2           White            6.3             0.300         0.34
# 3           White            8.1             0.280         0.40
# 4           White            7.2             0.230         0.32
# 5           White            7.2             0.230         0.32
# 6           White            8.1             0.280         0.40
# 7           White            6.2             0.320         0.16
# 8           White            7.0             0.270         0.36
# 9           White            6.3             0.300         0.34
# 10          White            8.1             0.220         0.43
# 11          White            8.1             0.270         0.41
# 12          White            8.6             0.230         0.40
# 13          White            7.9             0.180         0.37
# 14          White            6.6             0.160         0.40
# 15          White            8.3             0.420         0.62
# 16          White            6.6             0.170         0.38
# 17          White            6.3             0.480         0.04
# 18          White            6.2             0.660         0.48
# 19          White            7.4             0.340         0.42
# 20          White            6.5             0.310         0.14
# 21          White            6.2             0.660         0.48
# 22          White            6.4             0.310         0.38
# 23          White            6.8             0.260         0.42
# 24          White            7.6             0.670         0.14
# 25          White            6.6             0.270         0.41
# 26          White            7.0             0.250         0.32
# 27          White            6.9             0.240         0.35
# 28          White            7.0             0.280         0.39
# 29          White            7.4             0.270         0.48
# 30          White            7.2             0.320         0.36
# ...                          ...               ...          ...
# 1570        Red              6.2             0.510         0.14
# 1571        Red              6.4             0.360         0.53
# 1572        Red              6.4             0.380         0.14
# 1573        Red              7.3             0.690         0.32
# 1574        Red              6.0             0.580         0.20
# 1575        Red              5.6             0.310         0.78
# 1576        Red              7.5             0.520         0.40
# 1577        Red              8.0             0.300         0.63
# 1578        Red              6.2             0.700         0.15
# 1579        Red              6.8             0.670         0.15
# 1580        Red              6.2             0.560         0.09
# 1581        Red              7.4             0.350         0.33
# 1582        Red              6.2             0.560         0.09
# 1583        Red              6.1             0.715         0.10
# 1584        Red              6.2             0.460         0.29
# 1585        Red              6.7             0.320         0.44
# 1586        Red              7.2             0.390         0.44
# 1587        Red              7.5             0.310         0.41
# 1588        Red              5.8             0.610         0.11
# 1589        Red              7.2             0.660         0.33
# 1590        Red              6.6             0.725         0.20
# 1591        Red              6.3             0.550         0.15
# 1592        Red              5.4             0.740         0.09
# 1593        Red              6.3             0.510         0.13
# 1594        Red              6.8             0.620         0.08
# 1595        Red              6.2             0.600         0.08
# 1596        Red              5.9             0.550         0.10
# 1597        Red              6.3             0.510         0.13
# 1598        Red              5.9             0.645         0.12
# 1599        Red              6.0             0.310         0.47
#
#                    residual_sugar  chlorides  free_sulfur_dioxide  \
# wine number type
# 1           White           20.70      0.045                 45.0
# 2           White            1.60      0.049                 14.0
# 3           White            6.90      0.050                 30.0
# 4           White            8.50      0.058                 47.0
# 5           White            8.50      0.058                 47.0
# 6           White            6.90      0.050                 30.0
# 7           White            7.00      0.045                 30.0
# 8           White           20.70      0.045                 45.0
# 9           White            1.60      0.049                 14.0
# 10          White            1.50      0.044                 28.0
# 11          White            1.45      0.033                 11.0
# 12          White            4.20      0.035                 17.0
# 13          White            1.20      0.040                 16.0
# 14          White            1.50      0.044                 48.0
# 15          White           19.25      0.040                 41.0
# 16          White            1.50      0.032                 28.0
# 17          White            1.10      0.046                 30.0
# 18          White            1.20      0.029                 29.0
# 19          White            1.10      0.033                 17.0
# 20          White            7.50      0.044                 34.0
# 21          White            1.20      0.029                 29.0
# 22          White            2.90      0.038                 19.0
# 23          White            1.70      0.049                 41.0
# 24          White            1.50      0.074                 25.0
# 25          White            1.30      0.052                 16.0
# 26          White            9.00      0.046                 56.0
# 27          White            1.00      0.052                 35.0
# 28          White            8.70      0.051                 32.0
# 29          White            1.10      0.047                 17.0
# 30          White            2.00      0.033                 37.0
# ...                           ...        ...                  ...
# 1570        Red              1.90      0.056                 15.0
# 1571        Red              2.20      0.230                 19.0
# 1572        Red              2.20      0.038                 15.0
# 1573        Red              2.20      0.069                 35.0
# 1574        Red              2.40      0.075                 15.0
# 1575        Red             13.90      0.074                 23.0
# 1576        Red              2.20      0.060                 12.0
# 1577        Red              1.60      0.081                 16.0
# 1578        Red              5.10      0.076                 13.0
# 1579        Red              1.80      0.118                 13.0
# 1580        Red              1.70      0.053                 24.0
# 1581        Red              2.40      0.068                  9.0
# 1582        Red              1.70      0.053                 24.0
# 1583        Red              2.60      0.053                 13.0
# 1584        Red              2.10      0.074                 32.0
# 1585        Red              2.40      0.061                 24.0
# 1586        Red              2.60      0.066                 22.0
# 1587        Red              2.40      0.065                 34.0
# 1588        Red              1.80      0.066                 18.0
# 1589        Red              2.50      0.068                 34.0
# 1590        Red              7.80      0.073                 29.0
# 1591        Red              1.80      0.077                 26.0
# 1592        Red              1.70      0.089                 16.0
# 1593        Red              2.30      0.076                 29.0
# 1594        Red              1.90      0.068                 28.0
# 1595        Red              2.00      0.090                 32.0
# 1596        Red              2.20      0.062                 39.0
# 1597        Red              2.30      0.076                 29.0
# 1598        Red              2.00      0.075                 32.0
# 1599        Red              3.60      0.067                 18.0
#
#                    total_sulfur_dioxide  density    pH  sulphates  alcohol  \
# wine number type
# 1           White                 170.0  1.00100  3.00       0.45      8.8
# 2           White                 132.0  0.99400  3.30       0.49      9.5
# 3           White                  97.0  0.99510  3.26       0.44     10.1
# 4           White                 186.0  0.99560  3.19       0.40      9.9
# 5           White                 186.0  0.99560  3.19       0.40      9.9
# 6           White                  97.0  0.99510  3.26       0.44     10.1
# 7           White                 136.0  0.99490  3.18       0.47      9.6
# 8           White                 170.0  1.00100  3.00       0.45      8.8
# 9           White                 132.0  0.99400  3.30       0.49      9.5
# 10          White                 129.0  0.99380  3.22       0.45     11.0
# 11          White                  63.0  0.99080  2.99       0.56     12.0
# 12          White                 109.0  0.99470  3.14       0.53      9.7
# 13          White                  75.0  0.99200  3.18       0.63     10.8
# 14          White                 143.0  0.99120  3.54       0.52     12.4
# 15          White                 172.0  1.00020  2.98       0.67      9.7
# 16          White                 112.0  0.99140  3.25       0.55     11.4
# 17          White                  99.0  0.99280  3.24       0.36      9.6
# 18          White                  75.0  0.98920  3.33       0.39     12.8
# 19          White                 171.0  0.99170  3.12       0.53     11.3
# 20          White                 133.0  0.99550  3.22       0.50      9.5
# 21          White                  75.0  0.98920  3.33       0.39     12.8
# 22          White                 102.0  0.99120  3.17       0.35     11.0
# 23          White                 122.0  0.99300  3.47       0.48     10.5
# 24          White                 168.0  0.99370  3.05       0.51      9.3
# 25          White                 142.0  0.99510  3.42       0.47     10.0
# 26          White                 245.0  0.99550  3.25       0.50     10.4
# 27          White                 146.0  0.99300  3.45       0.44     10.0
# 28          White                 141.0  0.99610  3.38       0.53     10.5
# 29          White                 132.0  0.99140  3.19       0.49     11.6
# 30          White                 114.0  0.99060  3.10       0.71     12.3
# ...                                 ...      ...   ...        ...      ...
# 1570        Red                    34.0  0.99396  3.48       0.57     11.5
# 1571        Red                    35.0  0.99340  3.37       0.93     12.4
# 1572        Red                    25.0  0.99514  3.44       0.65     11.1
# 1573        Red                   104.0  0.99632  3.33       0.51      9.5
# 1574        Red                    50.0  0.99467  3.58       0.67     12.5
# 1575        Red                    92.0  0.99677  3.39       0.48     10.5
# 1576        Red                    20.0  0.99474  3.26       0.64     11.8
# 1577        Red                    29.0  0.99588  3.30       0.78     10.8
# 1578        Red                    27.0  0.99622  3.54       0.60     11.9
# 1579        Red                    20.0  0.99540  3.42       0.67     11.3
# 1580        Red                    32.0  0.99402  3.54       0.60     11.3
# 1581        Red                    26.0  0.99470  3.36       0.60     11.9
# 1582        Red                    32.0  0.99402  3.54       0.60     11.3
# 1583        Red                    27.0  0.99362  3.57       0.50     11.9
# 1584        Red                    98.0  0.99578  3.33       0.62      9.8
# 1585        Red                    34.0  0.99484  3.29       0.80     11.6
# 1586        Red                    48.0  0.99494  3.30       0.84     11.5
# 1587        Red                    60.0  0.99492  3.34       0.85     11.4
# 1588        Red                    28.0  0.99483  3.55       0.66     10.9
# 1589        Red                   102.0  0.99414  3.27       0.78     12.8
# 1590        Red                    79.0  0.99770  3.29       0.54      9.2
# 1591        Red                    35.0  0.99314  3.32       0.82     11.6
# 1592        Red                    26.0  0.99402  3.67       0.56     11.6
# 1593        Red                    40.0  0.99574  3.42       0.75     11.0
# 1594        Red                    38.0  0.99651  3.42       0.82      9.5
# 1595        Red                    44.0  0.99490  3.45       0.58     10.5
# 1596        Red                    51.0  0.99512  3.52       0.76     11.2
# 1597        Red                    40.0  0.99574  3.42       0.75     11.0
# 1598        Red                    44.0  0.99547  3.57       0.71     10.2
# 1599        Red                    42.0  0.99549  3.39       0.66     11.0
#
#                    quality
# wine number type
# 1           White        6
# 2           White        6
# 3           White        6
# 4           White        6
# 5           White        6
# 6           White        6
# 7           White        6
# 8           White        6
# 9           White        6
# 10          White        6
# 11          White        5
# 12          White        5
# 13          White        5
# 14          White        7
# 15          White        5
# 16          White        7
# 17          White        6
# 18          White        8
# 19          White        6
# 20          White        5
# 21          White        8
# 22          White        7
# 23          White        8
# 24          White        5
# 25          White        6
# 26          White        6
# 27          White        6
# 28          White        6
# 29          White        6
# 30          White        7
# ...                    ...
# 1570        Red          6
# 1571        Red          6
# 1572        Red          6
# 1573        Red          5
# 1574        Red          6
# 1575        Red          6
# 1576        Red          6
# 1577        Red          6
# 1578        Red          6
# 1579        Red          6
# 1580        Red          5
# 1581        Red          6
# 1582        Red          5
# 1583        Red          5
# 1584        Red          5
# 1585        Red          7
# 1586        Red          6
# 1587        Red          6
# 1588        Red          6
# 1589        Red          6
# 1590        Red          5
# 1591        Red          6
# 1592        Red          6
# 1593        Red          6
# 1594        Red          6
# 1595        Red          5
# 1596        Red          6
# 1597        Red          6
# 1598        Red          5
# 1599        Red          6
#
# [6497 rows x 12 columns]

# %%
df.describe() # Generate descriptive statistics on dataset
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6497 entries, (1, White) to (1599, Red)
# Data columns (total 12 columns):
# fixed_acidity           6497 non-null float64
# volatile_acidity        6497 non-null float64
# citric_acid             6497 non-null float64
# residual_sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free_sulfur_dioxide     6497 non-null float64
# total_sulfur_dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6497 non-null float64
# sulphates               6497 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 666.5+ KB

# %% [markdown]
# ### Distribution of Wine Quality

# %%
# probably dont need 

dfwhite['quality'].value_counts() # White wine quality count
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
dfred['quality'].value_counts() # Red wine quality count
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df['quality'].value_counts() # Red and White wine quality count
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
## Bar chart showing white wine quality breakdown 

sns.set(style='whitegrid')

sns.countplot(x = 'quality',
              data = dfwhite).set_title('White Wine Quality')
plt.show()

# %%
## Bar chart showing red wine quality breakdown 

sns.set(style='whitegrid')

sns.countplot(x = 'quality',
              data = dfred).set_title('Red Wine Quality')
plt.show()

# %%
## Bar chart showing wine quality breakdown 

sns.set(style='whitegrid')

sns.countplot(x = 'quality',
              data = df).set_title('Wine Quality')
plt.show()

# %%
## Want to attempt to show it all of wine quality - but white wines have a white bar, and red wine have a red bar?  

df_plot = df.groupby(['type', 'quality']).size().reset_index().pivot(columns='type', index='quality', values=0)

# %%
df_plot
# Out:
# type       Red   White
# quality
# 3         10.0    20.0
# 4         53.0   163.0
# 5        681.0  1457.0
# 6        638.0  2198.0
# 7        199.0   880.0
# 8         18.0   175.0
# 9          NaN     5.0

# %%
df_plot.plot(kind='bar', stacked=True, figsize=(15,8), color =['red','wheat']).set_title('Wine Quality Count')
# Out:
# Text(0.5,1,'Wine Quality Count')

# %% [markdown]
# ## Scatter plot for each independent variable against quality
# ### these have regression lines in the scatter plots - i still need to add titles, below these are seperate scatter plots.  thought these are useful for comparing white vs red as they increase in quality

# %% [markdown]
# #### Quality vs Fixed Acidity

# %%
sns.regplot(x=dfred["quality"], y=dfred["fixed_acidity"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["fixed_acidity"], color = 'wheat')

# %% [markdown]
# #### Quality vs Volatile Acidity

# %%
sns.regplot(x=dfred["quality"], y=dfred["volatile_acidity"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["volatile_acidity"], color = 'wheat')

# %% [markdown]
# #### Quality vs Citric Acid

# %%
sns.regplot(x=dfred["quality"], y=dfred["citric_acid"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["citric_acid"], color = 'wheat')

# %% [markdown]
# #### Quality vs Residual Sugar

# %%
sns.regplot(x=dfred["quality"], y=dfred["residual_sugar"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["residual_sugar"], color = 'wheat')

# %% [markdown]
# #### Quality vs Chlorides

# %%
sns.regplot(x=dfred["quality"], y=dfred["chlorides"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["chlorides"], color = 'wheat')

# %% [markdown]
# #### Quality vs Free Sulfur Dioxide

# %%
sns.regplot(x=dfred["quality"], y=dfred["free_sulfur_dioxide"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["free_sulfur_dioxide"], color = 'wheat')

# %% [markdown]
# #### Quality vs Total Sulfur Dioxide

# %%
sns.regplot(x=dfred["quality"], y=dfred["total_sulfur_dioxide"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["total_sulfur_dioxide"], color = 'wheat')

# %% [markdown]
# #### Quality vs Density

# %%
sns.regplot(x=dfred["quality"], y=dfred["density"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["density"], color = 'wheat')

# %% [markdown]
# #### Quality vs pH

# %%
sns.regplot(x=dfred["quality"], y=dfred["pH"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["pH"], color = 'wheat')

# %% [markdown]
# #### Quality vs Sulphates

# %%
sns.regplot(x=dfred["quality"], y=dfred["sulphates"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["sulphates"], color = 'wheat')

# %% [markdown]
# #### Quality vs Alcohol

# %%
sns.regplot(x=dfred["quality"], y=dfred["alcohol"], color='red')
sns.regplot(x=dfwhite["quality"], y=dfwhite["alcohol"], color = 'wheat')

# %% [markdown]
# # This was the first code i did for scatter plots .. just adding it in if we want to use this one over the one above

# %%
sns.set(style='whitegrid')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'fixed_acidity', ax=ax[0], color='red', figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'fixed_acidity', ax=ax[1], color='wheat') 

fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Fixed Acidity', fontsize = '14')


fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'volatile_acidity', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'volatile_acidity', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Volatile Acidity', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'citric_acid', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'citric_acid', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Citric Acid', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'residual_sugar', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'residual_sugar', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Residual Sugar', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'chlorides', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'chlorides', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Chlorides', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'free_sulfur_dioxide', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'free_sulfur_dioxide', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Free Sulfur Dioxide', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'total_sulfur_dioxide', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'total_sulfur_dioxide', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Total Sulfur Dioxide', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'density', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'density', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Density', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'pH', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'pH', ax=ax[1], color='wheat', zorder=1) 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs pH', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)
dfred.plot.scatter('quality', 'sulphates', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'sulphates', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=1)
ax[0].set_title('Quality vs Sulphates', fontsize = '14')

fig, ax = plt.subplots(ncols=2, nrows=1,sharey=True)

dfred.plot.scatter('quality', 'alcohol', ax=ax[0], color='red',figsize = (10,6))   # first plot
dfwhite.plot.scatter('quality' ,'alcohol', ax=ax[1], color='wheat') 
fig.subplots_adjust(hspace=0)
ax[0].set_title('Quality vs Alcohol', fontsize = '14')
# Out:
# Text(0.5,1,'Quality vs Alcohol')

# %% [markdown]
# ## Regression for each variable against quality -- only certain variable
#
# **THIS STILL NEEDS TO BE WRITTEN UP, WAS COPOY AND PASTED**
#
# Will look into correleation coefficients and regression coefficients
#
# Correleation - The correlation coefficient is a statistical measure that calculates the strength of the relationship between the relative movements of the two variables. The range of values for the correlation coefficient bounded by 1.0 on an absolute value basis or between -1.0 to 1.0. If the correlation coefficient is greater than 1.0 or less than -1.0, the correlation measurement is incorrect. (this is copy and pasted, don't use)
#
# Regression - Regression coefficients represent the mean change in the response variable for one unit of change in the predictor variable while holding other predictors in the model constant. This statistical control that regression provides is important because it isolates the role of one variable from all of the others in the model.  The key to understanding the coefficients is to think of them as slopes, and they’re often called slope coefficients (this is copy and pasted, don't use)

# %%
# Messing around with this, not sure if its the best thing for us to use because I don't understand it all 

smf.ols('quality ~ fixed_acidity + volatile_acidity + citric_acid + residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + density + pH + sulphates + alcohol', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Sun, 16 Dec 2018   Prob (F-statistic):               0.00
# Time:                        09:54:36   Log-Likelihood:                -7215.5
# No. Observations:                6497   AIC:                         1.445e+04
# Df Residuals:                    6485   BIC:                         1.454e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               55.7627     11.894      4.688      0.000      32.447      79.079
# fixed_acidity            0.0677      0.016      4.346      0.000       0.037       0.098
# volatile_acidity        -1.3279      0.077    -17.162      0.000      -1.480      -1.176
# citric_acid             -0.1097      0.080     -1.377      0.168      -0.266       0.046
# residual_sugar           0.0436      0.005      8.449      0.000       0.033       0.054
# chlorides               -0.4837      0.333     -1.454      0.146      -1.136       0.168
# free_sulfur_dioxide      0.0060      0.001      7.948      0.000       0.004       0.007
# total_sulfur_dioxide    -0.0025      0.000     -8.969      0.000      -0.003      -0.002
# density                -54.9669     12.137     -4.529      0.000     -78.760     -31.173
# pH                       0.4393      0.090      4.861      0.000       0.262       0.616
# sulphates                0.7683      0.076     10.092      0.000       0.619       0.917
# alcohol                  0.2670      0.017     15.963      0.000       0.234       0.300
# ==============================================================================
# Omnibus:                      144.075   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              324.712
# Skew:                          -0.006   Prob(JB):                     3.09e-71
# Kurtosis:                       4.095   Cond. No.                     2.49e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Correlation between variables for all wines 

corr = df.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df.columns)
ax.set_yticklabels(df.columns)
plt.show()

corr
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.219008     0.324436
# volatile_acidity           0.219008          1.000000    -0.377981
# citric_acid                0.324436         -0.377981     1.000000
# residual_sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free_sulfur_dioxide       -0.282735         -0.352557     0.133126
# total_sulfur_dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity              -0.111981   0.298195            -0.282735
# volatile_acidity           -0.196011   0.377124            -0.352557
# citric_acid                 0.142451   0.038998             0.133126
# residual_sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free_sulfur_dioxide         0.402871  -0.195045             1.000000
# total_sulfur_dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile_acidity                 -0.414476  0.271296  0.261454   0.225984
# citric_acid                       0.195242  0.096154 -0.329808   0.056197
# residual_sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free_sulfur_dioxide               0.720934  0.025717 -0.145854  -0.188457
# total_sulfur_dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
#
#                        alcohol   quality
# fixed_acidity        -0.095452 -0.076743
# volatile_acidity     -0.037640 -0.265699
# citric_acid          -0.010493  0.085532
# residual_sugar       -0.359415 -0.036980
# chlorides            -0.256916 -0.200666
# free_sulfur_dioxide  -0.179838  0.055463
# total_sulfur_dioxide -0.265740 -0.041385
# density              -0.686745 -0.305858
# pH                    0.121248  0.019506
# sulphates            -0.003029  0.038485
# alcohol               1.000000  0.444319
# quality               0.444319  1.000000

# %%
# Correlation between variables for white wines

corr_white = dfwhite.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr_white,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(dfwhite.columns)
ax.set_yticklabels(dfwhite.columns)
plt.show()

corr_white
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.022697     0.289181
# volatile_acidity          -0.022697          1.000000    -0.149472
# citric_acid                0.289181         -0.149472     1.000000
# residual_sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free_sulfur_dioxide       -0.049396         -0.097012     0.094077
# total_sulfur_dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity               0.089021   0.023086            -0.049396
# volatile_acidity            0.064286   0.070512            -0.097012
# citric_acid                 0.094212   0.114364             0.094077
# residual_sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free_sulfur_dioxide         0.299098   0.101392             1.000000
# total_sulfur_dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
# quality                    -0.097577  -0.209934             0.008158
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile_acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric_acid                       0.121131  0.149503 -0.163748   0.062331
# residual_sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free_sulfur_dioxide               0.615501  0.294210 -0.000618   0.059217
# total_sulfur_dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
# quality                          -0.174737 -0.307123  0.099427   0.053678
#
#                        alcohol   quality
# fixed_acidity        -0.120881 -0.113663
# volatile_acidity      0.067718 -0.194723
# citric_acid          -0.075729 -0.009209
# residual_sugar       -0.450631 -0.097577
# chlorides            -0.360189 -0.209934
# free_sulfur_dioxide  -0.250104  0.008158
# total_sulfur_dioxide -0.448892 -0.174737
# density              -0.780138 -0.307123
# pH                    0.121432  0.099427
# sulphates            -0.017433  0.053678
# alcohol               1.000000  0.435575
# quality               0.435575  1.000000

# %%
# Correlation between variables for red wines

corr_red = dfred.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr_red,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(dfred.columns)
ax.set_yticklabels(dfred.columns)
plt.show()

corr_red
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.256131     0.671703
# volatile_acidity          -0.256131          1.000000    -0.552496
# citric_acid                0.671703         -0.552496     1.000000
# residual_sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free_sulfur_dioxide       -0.153794         -0.010504    -0.060978
# total_sulfur_dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity               0.114777   0.093705            -0.153794
# volatile_acidity            0.001918   0.061298            -0.010504
# citric_acid                 0.143577   0.203823            -0.060978
# residual_sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free_sulfur_dioxide         0.187049   0.005562             1.000000
# total_sulfur_dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile_acidity                  0.076470  0.022026  0.234937  -0.260987
# citric_acid                       0.035533  0.364947 -0.541904   0.312770
# residual_sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free_sulfur_dioxide               0.667666 -0.021946  0.070377   0.051658
# total_sulfur_dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed_acidity        -0.061668  0.124052
# volatile_acidity     -0.202288 -0.390558
# citric_acid           0.109903  0.226373
# residual_sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free_sulfur_dioxide  -0.069408 -0.050656
# total_sulfur_dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
from sklearn.linear_model import LinearRegression 

# White Wine regression coefficient  

X = dfwhite.drop('quality', axis = 1) # creating variable X, with quality dropped since thats the dependent variable
lm = LinearRegression()
lm.fit(X,dfwhite.quality)
White_Regression = pd.DataFrame(list(zip(X.columns, lm.coef_)), 
             columns = ['features', 'estimatedCoefficients']) # naming new dataframe 
White_Regression
# Out:
#                 features  estimatedCoefficients
# 0          fixed_acidity               0.065520
# 1       volatile_acidity              -1.863177
# 2            citric_acid               0.022090
# 3         residual_sugar               0.081483
# 4              chlorides              -0.247277
# 5    free_sulfur_dioxide               0.003733
# 6   total_sulfur_dioxide              -0.000286
# 7                density            -150.284181
# 8                     pH               0.686344
# 9              sulphates               0.631476
# 10               alcohol               0.193476

# %%
# Red Wine regression coefficient  

X = dfred.drop('quality', axis = 1) # creating variable X, with quality dropped since thats the dependent variable
lm = LinearRegression()
lm.fit(X,dfred.quality)
Red_Regression = pd.DataFrame(list(zip(X.columns, lm.coef_)), 
             columns = ['features', 'estimatedCoefficients']) # naming the new dataframe 
Red_Regression
# Out:
#                 features  estimatedCoefficients
# 0          fixed_acidity               0.024991
# 1       volatile_acidity              -1.083590
# 2            citric_acid              -0.182564
# 3         residual_sugar               0.016331
# 4              chlorides              -1.874225
# 5    free_sulfur_dioxide               0.004361
# 6   total_sulfur_dioxide              -0.003265
# 7                density             -17.881164
# 8                     pH              -0.413653
# 9              sulphates               0.916334
# 10               alcohol               0.276198

# %% [markdown]
# ## What variables play a diference in red versus white wine

# %% [markdown]
# ## Use clustering to group wines together to offer recomendations?

# %% [markdown]
# * Complete for red and white wine seperate
# * X and Y will be the two most important variables for red and white wine (may be different)
# * Create clusters which will be our recomendation
# * Can theoretically talk about how this is how we would do a recomendation tool
# * Can look and see do clusters have similar quality ratings?
#
#
# White Wine - density and alcohol
#
# Red Wine - volatile acidity and alcohol

# %% [markdown]
# **White Wine**

# %%
#Scaling of data
ss_white = StandardScaler()
ss_white.fit_transform(dfwhite)
# Out:
# array([[ 1.72096961e-01, -8.17699008e-02,  2.13280202e-01, ...,
#         -3.49184257e-01, -1.39315246e+00,  1.37870140e-01],
#        [-6.57501128e-01,  2.15895632e-01,  4.80011213e-02, ...,
#          1.34184656e-03, -8.24275678e-01,  1.37870140e-01],
#        [ 1.47575110e+00,  1.74519434e-02,  5.43838363e-01, ...,
#         -4.36815783e-01, -3.36667007e-01,  1.37870140e-01],
#        ...,
#        [-4.20473102e-01, -3.79435433e-01, -1.19159198e+00, ...,
#         -2.61552731e-01, -9.05543789e-01,  1.37870140e-01],
#        [-1.60561323e+00,  1.16673788e-01, -2.82557040e-01, ...,
#         -9.62604939e-01,  1.85757201e+00,  1.26711420e+00],
#        [-1.01304317e+00, -6.77100966e-01,  3.78559282e-01, ...,
#         -1.48839409e+00,  1.04489089e+00,  1.37870140e-01]])

# %% [markdown]
# (1) k-means clustering
#
# In general, k-means is the first choice for clustering because of its simplicity. Here, the user has to define the number of clusters (Post on how to decide the number of clusters would be dealt later). The clusters are formed based on the closeness to the center value of the clusters. The initial center value is chosen randomly. K-means clustering is top-down approach, in the sense, we decide the number of clusters (k) and then group the data points into k clusters. - **stole from website need to sumarize**

# %%
#K means Clustering 
#def doKmeans(X, nclust=3):
 #   model = KMeans(nclust)
   # model.fit(X)
   # clust_labels = model.predict(X)
    #cent = model.cluster_centers_
    #return (clust_labels, cent)

#clust_labels, cent = doKmeans(dfwhite, 20)
#kmeans = pd.DataFrame(clust_labels)
#dfwhite.insert((dfwhite.shape[1]),'kmeans',kmeans)

# %%
#Plot the clusters obtained using k means
#fig = plt.figure()
#ax = fig.add_subplot(111)
#scatter = ax.scatter(dfwhite['density'],dfwhite['chlorides'],
                     #c=kmeans[0],s=4)
#ax.set_title('K-Means Clustering')
#ax.set_xlabel('Density')
#ax.set_ylabel('Chlorides')
#plt.colorbar(scatter)

# %%
#X = np.array(dfwhite.drop(['quality'], 1).astype(float))
#y = np.array(dfwhite['quality'])

# %%
# Scaling features that we are feeding into the model 

#scaler = MinMaxScaler()
#X_scaled = scaler.fit_transform(X)

# Building the k-means model 

#kmeans = KMeans(n_clusters=10) 
#kmeans.fit(X_scaled)

# %%
#kmeans = KMeans(n_clusters=10) 
#kmeans.fit(X)

# %%
#KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=600,
#    n_clusters=10, n_init=100, n_jobs=1, precompute_distances='auto',
#    random_state=None, tol=0.0001, verbose=0)

# %%
# Getting the values and plotting it
f1 = dfwhite['density'].values
f2 = dfwhite['chlorides'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='blue', s=7)

# %%
f1
# Out:
# array([1.001  , 0.994  , 0.9951 , ..., 0.99254, 0.98869, 0.98941])
